# %% [markdown]
# Project 1: Gradient-based Algorithms and Differentiable Programming

# %%
#imports

import logging
import math
import random
import numpy as np
import time
import torch as t
import torch.nn as nn
from torch import optim
from torch.nn import utils
import matplotlib.pyplot as plt

logger = logging.getLogger(__name__)

# %%
# environment parameters

FRAME_TIME = 0.1  # time interval
GRAVITY_ACCEL = 0.12  # gravity constant
BOOST_ACCEL = 0.18  # thrust constant
DRAG_COEFF = 0.34  # drag coefficient
AIR_DEN = 1.225 # density of air in normal conditions and can be changed with position
REF_AREA = 5 # Frontal Area which is considered here.

# # the following parameters are not being used in the sample code
# PLATFORM_WIDTH = 0.25  # landing platform width
# PLATFORM_HEIGHT = 0.06  # landing platform height
# ROTATION_ACCEL = 20  # rotation constant

# %%
# define system dynamics
# Notes: 
# 0. You only need to modify the "forward" function
# 1. All variables in "forward" need to be PyTorch tensors.
# 2. All math operations in "forward" has to be differentiable, e.g., default PyTorch functions.
# 3. Do not use inplace operations, e.g., x += 1. Please see the following section for an example that does not work.

class Dynamics(nn.Module):

    def __init__(self):
        super(Dynamics, self).__init__()

    @staticmethod
    def forward(state, action):

        """
        action: thrust or no thrust
        state[0] = y
        state[1] = y_dot
        """
        
        # Apply gravity
        # Note: Here gravity is used to change velocity which is the second element of the state vector
        # Normally, we would do x[1] = x[1] + gravity * delta_time
        # but this is not allowed in PyTorch since it overwrites one variable (x[1]) that is part of the computational graph to be differentiated.
        # Therefore, I define a tensor dx = [0., gravity * delta_time], and do x = x + dx. This is allowed... 
        delta_state_gravity = t.tensor([0., GRAVITY_ACCEL * FRAME_TIME])
        print(f'delta_state_gravity: {delta_state_gravity}')

        # Thrust
        # Note: Same reason as above. Need a 2-by-1 tensor.
        delta_state = BOOST_ACCEL * FRAME_TIME * t.tensor([0., -1.]) * action
        

        # Update velocity
        state = state + delta_state + delta_state_gravity
        

        half_velocity = t.mul(state, 0.5)

        # Drag State
        d_state = t.tensor([0., DRAG_COEFF * AIR_DEN * REF_AREA]) * t.square(half_velocity)

        # New_updated_state
        n_state = state - d_state


        # Update state
        # Note: Same as above. Use operators on matrices/tensors as much as possible. Do not use element-wise operators as they are considered inplace.
        step_mat = t.tensor([[1., FRAME_TIME],
                            [0., 1.]])
        state = t.matmul(step_mat, n_state)

        return state

# %%
# a deterministic controller
# Note:
# 0. You only need to change the network architecture in "__init__"
# 1. nn.Sigmoid outputs values from 0 to 1, nn.Tanh from -1 to 1
# 2. You have all the freedom to make the network wider (by increasing "dim_hidden") or deeper (by adding more lines to nn.Sequential)
# 3. Always start with something simple

class Controller(nn.Module):

    def __init__(self, dim_input, dim_hidden, dim_output):
        """
        dim_input: # of system states
        dim_output: # of actions
        dim_hidden: up to you
        """
        super(Controller, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(dim_input, dim_hidden),
            nn.Tanh(),
            nn.Linear(dim_hidden, dim_output),
            # You can add more layers here
            nn.Sigmoid()
        )

    def forward(self, state):
        action = self.network(state)
        return action

# %%
# the simulator that rolls out x(1), x(2), ..., x(T)
# Note:
# 0. Need to change "initialize_state" to optimize the controller over a distribution of initial states
# 1. self.action_trajectory and self.state_trajectory stores the action and state trajectories along time

class Simulation(nn.Module):

    def __init__(self, controller, dynamics, T):
        super(Simulation, self).__init__()
        self.state = self.initialize_state()
        self.controller = controller
        self.dynamics = dynamics
        self.T = T
        self.action_trajectory = []
        self.state_trajectory = []

    def forward(self, state):
        self.action_trajectory = []
        self.state_trajectory = []
        for _ in range(T):
            action = self.controller.forward(state)
            state = self.dynamics.forward(state, action)
            self.action_trajectory.append(action)
            self.state_trajectory.append(state)
        return self.error(state)

    @staticmethod
    def initialize_state():
        state = [0., 0.]  # TODO: need batch of initial states
        return t.tensor(state, requires_grad=False).float()

    def error(self, state):
        return state[0]**2 + state[1]**2

# %%
# set up the optimizer
# Note:
# 0. LBFGS is a good choice if you don't have a large batch size (i.e., a lot of initial states to consider simultaneously)
# 1. You can also try SGD and other momentum-based methods implemented in PyTorch
# 2. You will need to customize "visualize"
# 3. loss.backward is where the gradient is calculated (d_loss/d_variables)
# 4. self.optimizer.step(closure) is where gradient descent is done

class Optimize:
    def __init__(self, simulation):
        self.simulation = simulation
        self.parameters = simulation.controller.parameters()
        self.optimizer = optim.LBFGS(self.parameters, lr=0.01)

    def step(self):
        def closure():
            loss = self.simulation(self.simulation.state)
            self.optimizer.zero_grad()
            loss.backward()
            return loss
        self.optimizer.step(closure)
        return closure()
    
    def train(self, epochs):
        for epoch in range(epochs):
            loss = self.step()
            print('[%d] loss: %.3f' % (epoch + 1, loss))
            self.visualize()

    def visualize(self):
        data = np.array([self.simulation.state_trajectory[i].detach().numpy() for i in range(self.simulation.T)])
        x = data[:, 0]
        y = data[:, 1]
        plt.plot(x, y)
        plt.show()

# %%
# Now it's time to run the code!

T = 100  # number of time steps
dim_input = 2  # state space dimensions
dim_hidden = 6  # latent dimensions
dim_output = 1  # action space dimensions
d = Dynamics()  # define dynamics
c = Controller(dim_input, dim_hidden, dim_output)  # define controller
s = Simulation(c, d, T)  # define simulation
o = Optimize(s)  # define optimizer
o.train(40)  # solve the optimization problem
# Out:
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.6679e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.6654e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.4966e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.6520e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.1257e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.9083e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.9887e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0023], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.6280e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.5060e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.4608e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.5888e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.0275e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.7681e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.7997e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0021], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0022], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.3050e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.2155e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.1713e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.0763e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.2317e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.6310e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.2664e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.1290e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0016], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0017], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0018], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0019], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0020], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.9966e-07], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.7966e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.2835e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.1147e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.7367e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.4920e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.3774e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.3896e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.5243e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.7771e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.1433e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 9.6174e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0009], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0010], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0011], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0012], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0013], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0014], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0015], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.5465e-07], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.8174e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.0843e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.2484e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.1300e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.6225e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.2009e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.8633e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.6077e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.4317e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.3327e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.3080e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.3546e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.4695e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 9.6492e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0003], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0004], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0005], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0006], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0007], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0008], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# ...
# d_state: tensor([0.0000e+00, 2.2120e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.3746e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.5426e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.7158e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.8943e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.0779e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.2666e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.4604e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.6591e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.8628e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.0713e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.2846e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.5027e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.7254e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.9528e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.1847e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.4211e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.6619e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.9071e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.1566e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.4103e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.6682e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.9302e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.1963e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.4663e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.7403e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.0182e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.2998e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.5852e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.8743e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 9.1671e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 9.4633e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 9.7632e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0001], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000, 0.0002], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.9402e-08], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.1757e-07], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.6445e-07], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.6994e-07], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.3394e-07], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.0563e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.4370e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.8757e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.3723e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 2.9266e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 3.5384e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.2074e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 4.9334e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 5.7162e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 6.5554e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 7.4507e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 8.4018e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 9.4085e-06], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# d_state: tensor([0.0000e+00, 1.0470e-05], grad_fn=<MulBackward0>)
# delta_state_gravity: tensor([0.0000, 0.0120])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-cad548b34979> in <module>()
#       9 s = Simulation(c, d, T)  # define simulation
#      10 o = Optimize(s)  # define optimizer
# ---> 11 o.train(3)  # solve the optimization problem
#
# <ipython-input-55-f670d8403d27> in train(self, epochs)
#      24     def train(self, epochs):
#      25         for epoch in range(epochs):
# ---> 26             loss = self.step()
#      27             print('[%d] loss: %.3f' % (epoch + 1, loss))
#      28             self.visualize()
#
# <ipython-input-55-f670d8403d27> in step(self)
#      19             loss.backward()
#      20             return loss
# ---> 21         self.optimizer.step(closure)
#      22         return closure()
#      23
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     435                     # no use to re-evaluate that function here
#     436                     with torch.enable_grad():
# --> 437                         loss = float(closure())
#     438                     flat_grad = self._gather_flat_grad()
#     439                     opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# <ipython-input-55-f670d8403d27> in closure()
#      15     def step(self):
#      16         def closure():
# ---> 17             loss = self.simulation(self.simulation.state)
#      18             self.optimizer.zero_grad()
#      19             loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-54-d624d4374e45> in forward(self, state)
#      20         for _ in range(T):
#      21             action = self.controller.forward(state)
# ---> 22             state = self.dynamics.forward(state, action)
#      23             self.action_trajectory.append(action)
#      24             self.state_trajectory.append(state)
#
# <ipython-input-52-71f310ba1a3c> in forward(state, action)
#      41         # Drag State
#      42         d_state = t.tensor([0., DRAG_COEFF * AIR_DEN * REF_AREA]) * t.square(half_velocity)
# ---> 43         print(f'd_state: {d_state}')
#      44
#      45         # New_updated_state
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __format__(self, format_spec)
#     559         if self.dim() == 0:
#     560             return self.item().__format__(format_spec)
# --> 561         return object.__format__(self, format_spec)
#     562
#     563     def __ipow__(self, other):  # type: ignore[misc]
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __repr__(self)
#     201             return handle_torch_function(Tensor.__repr__, (self,), self)
#     202         # All strings are unicode in Python 3.
# --> 203         return torch._tensor_str._str(self)
#     204
#     205     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _str(self)
#     404 def _str(self):
#     405     with torch.no_grad():
# --> 406         return _str_intern(self)
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _str_intern(inp)
#     379                     tensor_str = _tensor_str(self.to_dense(), indent)
#     380                 else:
# --> 381                     tensor_str = _tensor_str(self, indent)
#     382
#     383     if self.layout != torch.strided:
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     240         return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     241     else:
# --> 242         formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     243         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     244
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor_str.py in __init__(self, tensor)
#      99             nonzero_finite_max = nonzero_finite_abs.max().double()
#     100
# --> 101             for value in nonzero_finite_vals:
#     102                 if value != torch.ceil(value):
#     103                     self.int_mode = False
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __iter__(self)
#     611                           'iterations executed (and might lead to errors or silently give '
#     612                           'incorrect results).', category=torch.jit.TracerWarning, stacklevel=2)
# --> 613         return iter(self.unbind(0))
#     614
#     615     def __hash__(self):
#
# KeyboardInterrupt:
